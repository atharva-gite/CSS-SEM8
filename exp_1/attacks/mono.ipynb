# %%
# cipher_text = """YPT BPMGGTCQT KJ YD RKJXGMF YPT YDX LKVT XHDUMUGT XGMKC YTZYJ NPKBP BDOGR UT RTBHFXYTR LHDW YPT JOXXGKTR WDCDMGXPMUTYKB BFXPTH OYKGKSKCQ YPT GTYYTH LHTIOTCBF MYYMBE LHDW M JYHKCQ JYH NKYP JKST E HTXHTJTCYKCQ YPT QKVTC WDCDMGXPMUTYKB BFXPTH.

# GTY OJ JTT NPMY TZMBYGF KJ LHTIOTCBF MYYMBE.

# YPT VTHF LDOCRMYKDC LDH LHTIOTCBF MCMGFJKJ KJ YPT BTHYMKCYF YPMY JXTBKLKB GTYYTHJ MCR GTYYTH BDWUKCMYKDCJ MXXTMH NKYP VMHKTR LHTIOTCBKTJ MGG YPHDOQP MCF QKVTC JTBYKDC DL NHKYYTC GMCQOMQT. MRRKYKDCMGGF, WMYYTH-DL-LMBYGF TVTHF JMWXGT DL YPMY GMCQOMQT JPMHTJ M BDWWDC XMYYTHC KC YPT RKJYHKUOYKDC DL GTYYTHJ. YD WMET KY WDHT BGTMH,

# YPT TCQGKJP MGXPMUTY PMJ 26 GTYYTHJ, PDNTVTH CDY MGG DL YPTW MHT OJTR TIOMGGF LHTIOTCYGF KC NHKYYTC TCQGKJP. YPT LHTIOTCBF DL OJT DL BTHYMKC GTYYTHJ VMHKTJ. LDH KCJYMCBT, KL FDO TZMWKCT GTYYTHJ KC M UDDE DH KC M CTNJXMXTH, FDO NKGG CDYKBT PDN DLYTC YPT GTYYTHJ T, Y, M, MCR D MXXTMH KC TCQGKJP NDHRJ IOKYT LHTIOTCYGF. PDNTVTH, TCQGKJP YTZYJ HMHTGF OJT GTYYTHJ A, Z, I, DH S. YPKJ LMBY BMC UT OJTR YD RTBHFXY. YPT YTHW "LHTIOTCBF MCMGFJKJ" HTLTHJ YD YPKJ WTYPDR.

# TMBP GTYYTH LDOCR KC YPT XGMKCYTZY KJ JOUJYKYOYTR NKYP M RKLLTHTCY GTYYTH KC M UMJKB JOUJYKYOYKDC BFXPTH, MCR MCF QKVTC BPMHMBYTH KC KYJ XGMKCYTZY KJ XTHXTYOMGGF BPMCQTR YD MC KRTCYKBMG GTYYTH KC YPT YTZY DL YPT BFXPTH. M BKXPTHYTZY WTJJMQT NKYP JTVTHMG HTXTYKYKDCJ DL YPT GTYYTH F, LDH KCJYMCBT, NDOGR KWXGF YD YPT BHFXYMCMGFJY YPMY F JYMCRJ KC LDH YPT GTYYTH M KL TVTHF KCJYMCBT DL YPT GTYYTH M MHT BDCVTHYTR YD YPT GTYYTH Z."""

# %%
cipher_text = ""
with open(r"D:\DMisc\CSS-SEM8\cipher_text.txt") as f:
    cipher_text = f.read()

cipher_text[:500]
# Out:
# 'BHFXYDQHMXPF YPT MHY MCR JBKTCBT DL JTBOHKCQ KCLDHWMYKDC BHFXYDQHMXPF KJ YPT XHMBYKBT MCR JYORF DL YTBPCKIOTJ LDH JTBOHKCQ BDWWOCKBMYKDC MCR RMYM KC YPT XHTJTCBT DL MRVTHJMHKTJ KY KJ M LOCRMWTCYMG MJXTBY DL WDRTHC BDWXOYKCQ MCR BDWWOCKBMYKDC JFJYTWJ TCMUGKCQ YPT XHDYTBYKDC DL JTCJKYKVT KCLDHWMYKDC JOBP MJ XMJJNDHRJ BHTRKY BMHR COWUTHJ MCR BDCLKRTCYKMG WTJJMQTJ YPT BDHT XOHXDJT DL BHFXYDQHMXPF KJ YD TCJOHT YPT BDCLKRTCYKMGKYF KCYTQHKYF MOYPTCYKBKYF MCR CDCHTXORKMYKDC DL KCLDHWMYKDC PKJYDHKBMGGF B'

# %%
# Relative frequency of letters in the English language
frequency_dict = {
    'a': 8.17,  'b': 1.49,  'c': 2.78,  'd': 4.25,  'e': 12.70,
    'f': 2.23,  'g': 2.02,  'h': 6.09,  'i': 6.97,  'j': 0.15,
    'k': 0.77,  'l': 4.03,  'm': 2.41,  'n': 6.75,  'o': 7.51,
    'p': 1.93,  'q': 0.10,  'r': 5.99,  's': 6.33,  't': 9.06,
    'u': 2.76,  'v': 0.98,  'w': 2.36,  'x': 0.15,  'y': 1.97,
    'z': 0.07
}

# %%
import numpy as np
import regex as re

# %%
import matplotlib.pyplot as plt

def plot_frequency(frequency_dict):
    frequency_dict_list = list(frequency_dict.items())
    frequency_dict_list.sort(key=lambda x: x[1], reverse=True)

    x = [i[0] for i in frequency_dict_list]
    y = [i[1] for i in frequency_dict_list]

    plt.bar(x, y)
    plt.xlabel('Letter')
    plt.ylabel('Frequency (%)')
    plt.title('Relative frequency of letters')

    for i, j in zip(x, y):
        format_to_2_decimal = "{:.2f}".format(j)
        plt.text(i, j, format_to_2_decimal, ha='center', va='bottom')

# Example usage:
plot_frequency(frequency_dict)

# %% [markdown]
# Take 1000 alphabets

# %%
def clean_text(text):
    # Remove special characters and numbers
    text = re.sub(r"[^a-zA-Z\s]", "", text)

    # Remove extra whitespace
    text = "".join(text.split())

    # Convert to lowercase
    text = text.upper()

    return text

# %%
cleaned_text = clean_text(cipher_text)
cleaned_text[:50]
# Out:
# 'BHFXYDQHMXPFYPTMHYMCRJBKTCBTDLJTBOHKCQKCLDHWMYKDCB'

# %%
mset = set(cleaned_text)
len(mset)
# Out:
# 26

# %%
from collections import Counter

# %%
def get_frequencies(text):
    # Count the frequency of each letter
    c = Counter(text)
    for key in c:
        c[key] = c[key] / len(text) * 100
    return c

# %%
cipher_freq = get_frequencies(cleaned_text)
cipher_freq
# Out:
# Counter({'T': 10.385992837246318,
#          'Y': 9.033028253083963,
#          'K': 8.595304417031437,
#          'C': 7.759649820931158,
#          'M': 7.6800636689216075,
#          'D': 7.162753680859531,
#          'J': 6.764822920811779,
#          'H': 6.247512932749701,
#          'B': 4.974134500596896,
#          'P': 3.8599283724631914,
#          'R': 3.5813768404297655,
#          'W': 3.3824114604058897,
#          'X': 3.263032232391564,
#          'G': 3.064066852367688,
#          'O': 2.9844807003581377,
#          'F': 2.904894548348587,
#          'Q': 2.626343016315161,
#          'L': 1.9498607242339834,
#          'U': 0.9550338241146041,
#          'N': 0.8356545961002786,
#          'V': 0.7958615200955035,
#          'E': 0.6366892160764027,
#          'I': 0.23875845602865103,
#          'S': 0.15917230401910068,
#          'Z': 0.11937922801432552,
#          'A': 0.03979307600477517})

# %%
eng_upper = []
for i, v in frequency_dict.items():
    eng_upper.append((i.upper(), v))

eng_upper.sort(key=lambda x: x[1], reverse=True)
eng_upper
# Out:
# [('E', 12.7),
#  ('T', 9.06),
#  ('A', 8.17),
#  ('O', 7.51),
#  ('I', 6.97),
#  ('N', 6.75),
#  ('S', 6.33),
#  ('H', 6.09),
#  ('R', 5.99),
#  ('D', 4.25),
#  ('L', 4.03),
#  ('C', 2.78),
#  ('U', 2.76),
#  ('M', 2.41),
#  ('W', 2.36),
#  ('F', 2.23),
#  ('G', 2.02),
#  ('Y', 1.97),
#  ('P', 1.93),
#  ('B', 1.49),
#  ('V', 0.98),
#  ('K', 0.77),
#  ('J', 0.15),
#  ('X', 0.15),
#  ('Q', 0.1),
#  ('Z', 0.07)]

# %%
cipher_freq
# Out:
# Counter({'T': 10.385992837246318,
#          'Y': 9.033028253083963,
#          'K': 8.595304417031437,
#          'C': 7.759649820931158,
#          'M': 7.6800636689216075,
#          'D': 7.162753680859531,
#          'J': 6.764822920811779,
#          'H': 6.247512932749701,
#          'B': 4.974134500596896,
#          'P': 3.8599283724631914,
#          'R': 3.5813768404297655,
#          'W': 3.3824114604058897,
#          'X': 3.263032232391564,
#          'G': 3.064066852367688,
#          'O': 2.9844807003581377,
#          'F': 2.904894548348587,
#          'Q': 2.626343016315161,
#          'L': 1.9498607242339834,
#          'U': 0.9550338241146041,
#          'N': 0.8356545961002786,
#          'V': 0.7958615200955035,
#          'E': 0.6366892160764027,
#          'I': 0.23875845602865103,
#          'S': 0.15917230401910068,
#          'Z': 0.11937922801432552,
#          'A': 0.03979307600477517})

# %%
cipher_freq_arr = []
for i, v in cipher_freq.items():
    cipher_freq_arr.append((i, v))

cipher_freq_arr.sort(key=lambda x: x[1], reverse=True)
cipher_freq_arr
# Out:
# [('T', 10.385992837246318),
#  ('Y', 9.033028253083963),
#  ('K', 8.595304417031437),
#  ('C', 7.759649820931158),
#  ('M', 7.6800636689216075),
#  ('D', 7.162753680859531),
#  ('J', 6.764822920811779),
#  ('H', 6.247512932749701),
#  ('B', 4.974134500596896),
#  ('P', 3.8599283724631914),
#  ('R', 3.5813768404297655),
#  ('W', 3.3824114604058897),
#  ('X', 3.263032232391564),
#  ('G', 3.064066852367688),
#  ('O', 2.9844807003581377),
#  ('F', 2.904894548348587),
#  ('Q', 2.626343016315161),
#  ('L', 1.9498607242339834),
#  ('U', 0.9550338241146041),
#  ('N', 0.8356545961002786),
#  ('V', 0.7958615200955035),
#  ('E', 0.6366892160764027),
#  ('I', 0.23875845602865103),
#  ('S', 0.15917230401910068),
#  ('Z', 0.11937922801432552),
#  ('A', 0.03979307600477517)]

# %%
mapping = {}
# cipher to original mapping

for i in range(len(cipher_freq_arr)):
    mapping[cipher_freq_arr[i][0]] = eng_upper[i][0]

# %%
mapping
# Out:
# {'T': 'E',
#  'Y': 'T',
#  'K': 'A',
#  'C': 'O',
#  'M': 'I',
#  'D': 'N',
#  'J': 'S',
#  'H': 'H',
#  'B': 'R',
#  'P': 'D',
#  'R': 'L',
#  'W': 'C',
#  'X': 'U',
#  'G': 'M',
#  'O': 'W',
#  'F': 'F',
#  'Q': 'G',
#  'L': 'Y',
#  'U': 'P',
#  'N': 'B',
#  'V': 'V',
#  'E': 'K',
#  'I': 'J',
#  'S': 'X',
#  'Z': 'Q',
#  'A': 'Z'}

# %%
len(mapping)
# Out:
# 26

# %%
def substitute(text, mapping):
    # Substitute each letter in the text using the mapping
    return "".join([mapping.get(c, c) for c in text])

# %%
recovered_text = substitute(cipher_text, mapping)

# %%
recovered_text
# Out:
# 'RHFUTNGHIUDF TDE IHT IOL SRAEORE NY SERWHAOG AOYNHCITANO RHFUTNGHIUDF AS TDE UHIRTARE IOL STWLF NY TERDOAJWES YNH SERWHAOG RNCCWOARITANO IOL LITI AO TDE UHESEORE NY ILVEHSIHAES AT AS I YWOLICEOTIM ISUERT NY CNLEHO RNCUWTAOG IOL RNCCWOARITANO SFSTECS EOIPMAOG TDE UHNTERTANO NY SEOSATAVE AOYNHCITANO SWRD IS UISSBNHLS RHELAT RIHL OWCPEHS IOL RNOYALEOTAIM CESSIGES TDE RNHE UWHUNSE NY RHFUTNGHIUDF AS TN EOSWHE TDE RNOYALEOTAIMATF AOTEGHATF IWTDEOTARATF IOL ONOHEUWLAITANO NY AOYNHCITANO DASTNHARIMMF RHFUTNGHIUDF DIS PEEO WSEL YNH CAMATIHF IOL LAUMNCITAR RNCCWOARITANO NOE NY TDE EIHMAEST KONBO SFSTECS TDE RIESIH RAUDEH BIS WSEL PF ZWMAWS RIESIH TN SERWHE CAMATIHF CESSIGES TDAS SACUME SWPSTATWTANO RAUDEH SDAYTEL TDE METTEHS NY TDE IMUDIPET PF I YAQEL OWCPEH CIKAOG TDE CESSIGE WOHEILIPME TN WOIWTDNHAXEL UIHTAES IS RNCCWOARITANO TERDONMNGAES EVNMVEL SN LAL TDE RNCUMEQATF NY RHFUTNGHIUDAR TERDOAJWES MEILAOG TN TDE LEVEMNUCEOT NY CNHE SNUDASTARITEL CETDNLS SWRD IS TDE EOAGCI CIRDAOE WSEL PF TDE GEHCIOS AO BNHML BIH AA CNLEHO RHFUTNGHIUDF AS PWAMT NO CITDECITARIM UHAORAUMES IOL RNCUWTEH SRAEORE WTAMAXAOG IMGNHATDCS IOL UHNTNRNMS TN SERWHE LAGATIM LITI TDESE IMGNHATDCS YIMM AOTN TBN CIAO RITEGNHAES SFCCETHAR IOL ISFCCETHAR SFCCETHAR EORHFUTANO WSES I SAOGME KEF YNH PNTD EORHFUTANO IOL LERHFUTANO CIKAOG AT EYYARAEOT PWT HEJWAHAOG SERWHE KEF LASTHAPWTANO EQICUMES AORMWLE TDE ILVIOREL EORHFUTANO STIOLIHL IES IOL LITI EORHFUTANO STIOLIHL LES ISFCCETHAR EORHFUTANO NO TDE NTDEH DIOL WSES I UIAH NY KEFS I UWPMAR KEF YNH EORHFUTANO IOL I UHAVITE KEF YNH LERHFUTANO TDAS CETDNL AS BALEMF WSEL AO SERWHE RNCCWOARITANO UHNTNRNMS MAKE SSMTMS IOL AO LAGATIM SAGOITWHES NOE NY TDE KEF RDIMMEOGES AO RHFUTNGHIUDF AS PIMIORAOG SERWHATF BATD UEHYNHCIORE STHNOG EORHFUTANO IMGNHATDCS NYTEO HEJWAHE SAGOAYARIOT RNCUWTITANOIM HESNWHRES BDARD RIO SMNB LNBO SFSTECS DNBEVEH TDE HIUAL ILVIORECEOT AO RNCUWTAOG UNBEH IOL TDE LEVEMNUCEOT NY SUERAIMAXEL DIHLBIHE DIVE CATAGITEL TDESE RDIMMEOGES EOIPMAOG TDE BALESUHEIL WSE NY RHFUTNGHIUDF AO EVEHFLIF IUUMARITANOS RHFUTNGHIUDF AS ONT BATDNWT ATS MACATITANOS TDE STHEOGTD NY RHFUTNGHIUDAR SFSTECS HEMAES DEIVAMF NO TDE SERHERF NY KEFS IOL TDE SERWHATF NY WOLEHMFAOG IMGNHATDCS BATD TDE ILVEOT NY JWIOTWC RNCUWTAOG THILATANOIM RHFUTNGHIUDAR CETDNLS IHE IT HASK NY PEAOG PHNKEO UHNCUTAOG TDE LEVEMNUCEOT NY JWIOTWCHESASTIOT IMGNHATDCS ILLATANOIMMF TDE DWCIO EMECEOT HECIAOS I SAGOAYARIOT VWMOEHIPAMATF BEIK UISSBNHLS UDASDAOG ITTIRKS IOL SNRAIM EOGAOEEHAOG RIO RNCUHNCASE EVEO TDE CNST HNPWST RHFUTNGHIUDAR SFSTECS AO RNORMWSANO RHFUTNGHIUDF AS IO ESSEOTAIM TNNM AO TDE LAGATIM IGE SIYEGWIHLAOG NWH LITI IOL RNCCWOARITANO YHNC WOIWTDNHAXEL IRRESS ATS RNOTAOWNWS EVNMWTANO HEYMERTS TDE NOGNAOG PITTME PETBEEO SERWHAOG AOYNHCITANO IOL TDE EVEHUHESEOT TDHEIT NY RFPEHITTIRKS IS TERDONMNGF ILVIORES SN TNN BAMM TDE CETDNLS NY RHFUTNGHIUDF EOSWHAOG TDIT AT HECIAOS I RNHOEHSTNOE NY AOYNHCITANO SERWHATF\n'

# %%
actual_key = ['M', 'U', 'B', 'R', 'T', 'L', 'Q', 'P', 'K', 'A', 'E', 'G', 'W', 'C', 'D', 'X', 'I', 'H', 'J', 'Y', 'O', 'V', 'N', 'Z', 'F', 'S']

aplhabets = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

actual_mapping = {}
for i in range(len(actual_key)):
    actual_mapping[actual_key[i]] = aplhabets[i]

# %%
attacked_cipher_mapped_to_actual = list(mapping.items())
actual_mapping_list = list(actual_mapping.items())

attacked_cipher_mapped_to_actual.sort(key=lambda x: x[0])
actual_mapping_list.sort(key=lambda x: x[0])
attacked_cipher_mapped_to_actual
# Out:
# [('A', 'Z'),
#  ('B', 'R'),
#  ('C', 'O'),
#  ('D', 'N'),
#  ('E', 'K'),
#  ('F', 'F'),
#  ('G', 'M'),
#  ('H', 'H'),
#  ('I', 'J'),
#  ('J', 'S'),
#  ('K', 'A'),
#  ('L', 'Y'),
#  ('M', 'I'),
#  ('N', 'B'),
#  ('O', 'W'),
#  ('P', 'D'),
#  ('Q', 'G'),
#  ('R', 'L'),
#  ('S', 'X'),
#  ('T', 'E'),
#  ('U', 'P'),
#  ('V', 'V'),
#  ('W', 'C'),
#  ('X', 'U'),
#  ('Y', 'T'),
#  ('Z', 'Q')]

# %%
actual_mapping_list
# Out:
# [('A', 'J'),
#  ('B', 'C'),
#  ('C', 'N'),
#  ('D', 'O'),
#  ('E', 'K'),
#  ('F', 'Y'),
#  ('G', 'L'),
#  ('H', 'R'),
#  ('I', 'Q'),
#  ('J', 'S'),
#  ('K', 'I'),
#  ('L', 'F'),
#  ('M', 'A'),
#  ('N', 'W'),
#  ('O', 'U'),
#  ('P', 'H'),
#  ('Q', 'G'),
#  ('R', 'D'),
#  ('S', 'Z'),
#  ('T', 'E'),
#  ('U', 'B'),
#  ('V', 'V'),
#  ('W', 'M'),
#  ('X', 'P'),
#  ('Y', 'T'),
#  ('Z', 'X')]

# %%
def find_how_many_correctly_matched_and_how_many_incorrectly(cipher_mapping, actual_mapping):
    correct = 0
    incorrect = 0
    
    corrects = []
    incorrects = []
    
    for k, v in cipher_mapping.items():
        if v == actual_mapping[k]:
            correct += 1
            corrects.append((k, v))
        else:
            incorrect += 1
            incorrects.append((k, v))
        
    
    
    return correct, incorrect, corrects, incorrects

# %%
correct, incorrect, corrects, incorrects = find_how_many_correctly_matched_and_how_many_incorrectly(mapping, actual_mapping)

# %%
print(correct)
corrects
# Out:
# 6
# [('T', 'E'), ('Y', 'T'), ('J', 'S'), ('Q', 'G'), ('V', 'V'), ('E', 'K')]

# %%
print(incorrect)
incorrects
# Out:
# 20
# [('K', 'A'),
#  ('C', 'O'),
#  ('M', 'I'),
#  ('D', 'N'),
#  ('H', 'H'),
#  ('B', 'R'),
#  ('P', 'D'),
#  ('R', 'L'),
#  ('W', 'C'),
#  ('X', 'U'),
#  ('G', 'M'),
#  ('O', 'W'),
#  ('F', 'F'),
#  ('L', 'Y'),
#  ('U', 'P'),
#  ('N', 'B'),
#  ('I', 'J'),
#  ('S', 'X'),
#  ('Z', 'Q'),
#  ('A', 'Z')]

# %%
x = np.array(list(cipher_freq.keys()))
y = np.array(list(cipher_freq.values()))

# plot 
import matplotlib.pyplot as plt
plt.bar(x, y)
plt.xlabel('Letter')
plt.ylabel('Frequency (%)')
plt.title('Relative frequency of letters in the English language')

# annotate it
for i, j in zip(x, y):
    plt.text(i, j, str(j), ha='center', va='bottom')

# %%
plot_frequency(frequency_dict)

# %%
plot_frequency(cipher_freq)
