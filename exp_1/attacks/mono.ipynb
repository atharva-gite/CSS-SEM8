# 'DSNS CU QGBJDSN JKB JDBMUQGW ZDQNQZJSN JSOJ CG QVV ZQYU KCJD GB UYSZCQV ZDQNQZJSNU BN UYQZSU RMUJ Q USQTVSUU UJNSQT BX VSJJSNU ZBGJCGMCGE JDS RBMNGSL XNBT JDS VQUJ JSOJ QGW JQFCGE LBM WSSYSN CGJB JDCU MGCHMS SOYSNCSGZS QU LBM NSQW BG LBMN TCGW TQL ASECG JB KQGWSN JNLCGE JB XCGW TSQGCGE CG JDS USSTCGEVL SGWVSUU UJNCGE BX VSJJSNU YSNDQYU LBM QNS JNLCGE JB WCUZBISN YQJJSNGU DCWWSG KCJDCG JDS JSOJ BN TQLAS LBM QNS RMUJ SGRBLCGE JDS ZDQVVSGES BX FSSYCGE XBZMU QU JDS JSOJ XVBKU SGWVSUUVL KCJDBMJ Q ANS'

# %%
# Relative frequency of letters in the English language
frequency_dict = {
    'a': 8.17,  'b': 1.49,  'c': 2.78,  'd': 4.25,  'e': 12.70,
    'f': 2.23,  'g': 2.02,  'h': 6.09,  'i': 6.97,  'j': 0.15,
    'k': 0.77,  'l': 4.03,  'm': 2.41,  'n': 6.75,  'o': 7.51,
    'p': 1.93,  'q': 0.10,  'r': 5.99,  's': 6.33,  't': 9.06,
    'u': 2.76,  'v': 0.98,  'w': 2.36,  'x': 0.15,  'y': 1.97,
    'z': 0.07
}

# %%
import numpy as np
import re

# %%
import matplotlib.pyplot as plt

def plot_frequency(frequency_dict):
    frequency_dict_list = list(frequency_dict.items())
    frequency_dict_list.sort(key=lambda x: x[1], reverse=True)

    x = [i[0] for i in frequency_dict_list]
    y = [i[1] for i in frequency_dict_list]

    plt.bar(x, y)
    plt.xlabel('Letter')
    plt.ylabel('Frequency (%)')
    plt.title('Relative frequency of letters')

    for i, j in zip(x, y):
        format_to_2_decimal = "{:.2f}".format(j)
        plt.text(i, j, format_to_2_decimal, ha='center', va='bottom')

# Example usage:
plot_frequency(frequency_dict)

# %% [markdown]
# Take 1000 alphabets

# %%
def clean_text(text):
    # Remove special characters and numbers
    text = re.sub(r"[^a-zA-Z\s]", "", text)

    # Remove extra whitespace
    text = "".join(text.split())

    # Convert to lowercase
    text = text.upper()

    return text

# %%
cleaned_text = clean_text(cipher_text)
cleaned_text[:50]
# Out:
# 'DSNSCUQGBJDSNJKBJDBMUQGWZDQNQZJSNJSOJCGQVVZQYUKCJD'

# %%
mset = set(cleaned_text)
len(mset)
# Out:
# 26

# %%
from collections import Counter

# %%
def get_frequencies(text):
    # Count the frequency of each letter
    c = Counter(text)
    for key in c:
        c[key] = c[key] / len(text) * 100
    return c

# %%
cipher_freq = get_frequencies(cleaned_text)
cipher_freq
# Out:
# Counter({'D': 4.519774011299435,
#          'S': 13.333333333333334,
#          'N': 5.536723163841808,
#          'C': 6.3841807909604515,
#          'U': 5.875706214689266,
#          'Q': 7.401129943502825,
#          'G': 8.192090395480225,
#          'B': 7.909604519774012,
#          'J': 9.661016949152543,
#          'K': 0.96045197740113,
#          'M': 3.7853107344632773,
#          'W': 3.5593220338983054,
#          'Z': 2.937853107344633,
#          'O': 0.4519774011299435,
#          'V': 3.5028248587570623,
#          'Y': 2.3163841807909606,
#          'R': 0.6214689265536724,
#          'T': 2.2033898305084745,
#          'X': 2.0903954802259888,
#          'E': 2.4293785310734464,
#          'L': 3.3333333333333335,
#          'F': 1.1864406779661016,
#          'H': 0.22598870056497175,
#          'A': 0.7909604519774011,
#          'I': 0.6779661016949152,
#          'P': 0.11299435028248588})

# %%
eng_upper = []
for i, v in frequency_dict.items():
    eng_upper.append((i.upper(), v))

eng_upper.sort(key=lambda x: x[1], reverse=True)
eng_upper
# Out:
# [('E', 12.7),
#  ('T', 9.06),
#  ('A', 8.17),
#  ('O', 7.51),
#  ('I', 6.97),
#  ('N', 6.75),
#  ('S', 6.33),
#  ('H', 6.09),
#  ('R', 5.99),
#  ('D', 4.25),
#  ('L', 4.03),
#  ('C', 2.78),
#  ('U', 2.76),
#  ('M', 2.41),
#  ('W', 2.36),
#  ('F', 2.23),
#  ('G', 2.02),
#  ('Y', 1.97),
#  ('P', 1.93),
#  ('B', 1.49),
#  ('V', 0.98),
#  ('K', 0.77),
#  ('J', 0.15),
#  ('X', 0.15),
#  ('Q', 0.1),
#  ('Z', 0.07)]

# %%
cipher_freq
# Out:
# Counter({'D': 4.519774011299435,
#          'S': 13.333333333333334,
#          'N': 5.536723163841808,
#          'C': 6.3841807909604515,
#          'U': 5.875706214689266,
#          'Q': 7.401129943502825,
#          'G': 8.192090395480225,
#          'B': 7.909604519774012,
#          'J': 9.661016949152543,
#          'K': 0.96045197740113,
#          'M': 3.7853107344632773,
#          'W': 3.5593220338983054,
#          'Z': 2.937853107344633,
#          'O': 0.4519774011299435,
#          'V': 3.5028248587570623,
#          'Y': 2.3163841807909606,
#          'R': 0.6214689265536724,
#          'T': 2.2033898305084745,
#          'X': 2.0903954802259888,
#          'E': 2.4293785310734464,
#          'L': 3.3333333333333335,
#          'F': 1.1864406779661016,
#          'H': 0.22598870056497175,
#          'A': 0.7909604519774011,
#          'I': 0.6779661016949152,
#          'P': 0.11299435028248588})

# %%
cipher_freq_arr = []
for i, v in cipher_freq.items():
    cipher_freq_arr.append((i, v))

cipher_freq_arr.sort(key=lambda x: x[1], reverse=True)
cipher_freq_arr
# Out:
# [('S', 13.333333333333334),
#  ('J', 9.661016949152543),
#  ('G', 8.192090395480225),
#  ('B', 7.909604519774012),
#  ('Q', 7.401129943502825),
#  ('C', 6.3841807909604515),
#  ('U', 5.875706214689266),
#  ('N', 5.536723163841808),
#  ('D', 4.519774011299435),
#  ('M', 3.7853107344632773),
#  ('W', 3.5593220338983054),
#  ('V', 3.5028248587570623),
#  ('L', 3.3333333333333335),
#  ('Z', 2.937853107344633),
#  ('E', 2.4293785310734464),
#  ('Y', 2.3163841807909606),
#  ('T', 2.2033898305084745),
#  ('X', 2.0903954802259888),
#  ('F', 1.1864406779661016),
#  ('K', 0.96045197740113),
#  ('A', 0.7909604519774011),
#  ('I', 0.6779661016949152),
#  ('R', 0.6214689265536724),
#  ('O', 0.4519774011299435),
#  ('H', 0.22598870056497175),
#  ('P', 0.11299435028248588)]

# %%
mapping = {}
# cipher to original mapping

for i in range(len(cipher_freq_arr)):
    mapping[cipher_freq_arr[i][0]] = eng_upper[i][0]

# %%
mapping
# Out:
# {'S': 'E',
#  'J': 'T',
#  'G': 'A',
#  'B': 'O',
#  'Q': 'I',
#  'C': 'N',
#  'U': 'S',
#  'N': 'H',
#  'D': 'R',
#  'M': 'D',
#  'W': 'L',
#  'V': 'C',
#  'L': 'U',
#  'Z': 'M',
#  'E': 'W',
#  'Y': 'F',
#  'T': 'G',
#  'X': 'Y',
#  'F': 'P',
#  'K': 'B',
#  'A': 'V',
#  'I': 'K',
#  'R': 'J',
#  'O': 'X',
#  'H': 'Q',
#  'P': 'Z'}

# %%
len(mapping)
# Out:
# 26

# %%
def substitute(text, mapping):
    # Substitute each letter in the text using the mapping
    return "".join([mapping.get(c, c) for c in text])

# %%
recovered_text = substitute(cipher_text, mapping)

# %%
recovered_text
# Out:
# 'REHE NS IAOTREH TBO TRODSIAL MRIHIMTEH TEXT NA ICC MIFS BNTR AO SFEMNIC MRIHIMTEHS OH SFIMES JDST I SEIGCESS STHEIG OY CETTEHS MOATNADNAW TRE JODHAEU YHOG TRE CIST TEXT IAL TIPNAW UOD LEEFEH NATO TRNS DANQDE EXFEHNEAME IS UOD HEIL OA UODH GNAL GIU VEWNA TO BIALEH THUNAW TO YNAL GEIANAW NA TRE SEEGNAWCU EALCESS STHNAW OY CETTEHS FEHRIFS UOD IHE THUNAW TO LNSMOKEH FITTEHAS RNLLEA BNTRNA TRE TEXT OH GIUVE UOD IHE JDST EAJOUNAW TRE MRICCEAWE OY PEEFNAW YOMDS IS TRE TEXT YCOBS EALCESSCU BNTRODT I VHEIP TRNS NS AOT JDST I TEST OY UODH HEILNAW IVNCNTU VDT ICSO I MRICCEAWE TO UODH EALDHIAME IAL GEATIC YOHTNTDLE PEEF WONAW IAL STIU STHOAW UODKE ICHEILU FHOKEA UODHSECY MIFIVCE OY RIALCNAW TRE YNHST TEXT AOB CETS SEE NY UOD MIA MOAQDEH TRNS OAE TOO HEGEGVEH TRNS NS AOT I HIME TREHE NS AO FHESSDHE TO YNANSR QDNMPCU JDST TIPE UODH TNGE IAL EAJOU TRE EXFEHNEAME UODKE ICHEILU GILE NT TRNS YIH SO UODKE WOT BRIT NT TIPES TO GIPE NT TO TRE EAL OAME IWINA PEEF UODH EUES COMPEL OA TRE SMHEEA YOCCOB TRE CETTEHS IS TREU SFNCC IMHOSS TRE FIWE OAE IYTEH TRE OTREH HEGEGVEH TO VHEITRE PEEF UODH GNAL YOMDSEL IAL LOAT CET UODHSECY WET LNSTHIMTEL IS UOD IFFHOIMR TR
TIPES TO GIPE NT TO TRE EAL OAME IWINA PEEF UODH EUES COMPEL OA TRE SMHEEA YOCCOB TRE CETTEHS IS TREU SFNCC IMHOSS TRE FIWE OAE IYTEH TRE OTREH HEGEGVEH TO VHEITRE PEEF UODH GNAL YOMDSEL IAL LOAT CET UODHSECY WET LNSTHIMTEL IS UOD IFFHOIMR TRE GNLFONAT UOD GNWRT STIHT TO YEEC I SEASE OY LEJI KD IAL TRITS OPIU TRNS TEXT NS GEIAT TO VE HEFETNTNKE IAL GNAL ADGVNAW EGVHIME TRE GOAOTOAU IAL CET NT RECF UOD MCEIH UODH GNAL OY LNSTHIMTNOAS UOD IHE AOB FIST TRE GNLFONAT IAL UOD MIA SEE TRE YNANSR CNAE OA TRE ROHNZOA PEEF FDSRNAW PEEF YOMDSNAW PEEF HEILNAW UODKE ICGOST GILE NT LOAT CET UODH GNAL BIALEH AOB STIU STHOAW IAL PEEF WONAW UOD IHE NA TRE YNAIC STHETMR IAL TRE EAL NS NA SNWRT JDST I CNTTCE VNT GOHE IAL UOD BNCC RIKE MOGFCETEL TRNS MRICCEAWE MOAWHITDCITNOAS OA GIPNAW NT TRNS YIH UODHE ICGOST TREHE PEEF UODH EUES OA TRE FHNZE PEEF UODH YOMDS SRIHF IAL UODH GNAL MCEIH IAL BREA UOD HEIMR TRE EAL UOD MIA VE FHODL OY UODHSECY YOH RIKNAW TRE LETEHGNAITNOA IAL GEATIC STHEAWTR TO YNANSR TRNS DANQDE MRICCEAWE UODHE AOB NA TRE YNAIC YEB MRIHIMTEHS PEEF FDSRNAW PEEF YOMDSNAW IAL WET HEILU TO EAJOU TRE SITNSYIMTNOA OY HEIMRNAW TRE EAL UODKE LOAE NT IWINA MOAWHITDCITNOAS UODKE MOGFCETEL TRNS MRICCEAWE IAL MIA AOB EAJOU TRE SEASE OY IMMOGFCNSRGEAT'

# %%
actual_key = ['Q', 'A', 'Z', 'W', 'S', 'X', 'E', 'D', 'C', 'R', 'F', 'V', 'T', 'G', 'B', 'Y', 'H', 'N', 'U', 'J', 'M', 'I', 'K', 'O', 'L', 'P']


aplhabets = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

actual_mapping = {}
for i in range(len(actual_key)):
    actual_mapping[actual_key[i]] = aplhabets[i]

# %%
attacked_cipher_mapped_to_actual = list(mapping.items())
actual_mapping_list = list(actual_mapping.items())

attacked_cipher_mapped_to_actual.sort(key=lambda x: x[0])
actual_mapping_list.sort(key=lambda x: x[0])
attacked_cipher_mapped_to_actual
# Out:
# [('A', 'V'),
#  ('B', 'O'),
#  ('C', 'N'),
#  ('D', 'R'),
#  ('E', 'W'),
#  ('F', 'P'),
#  ('G', 'A'),
#  ('H', 'Q'),
#  ('I', 'K'),
#  ('J', 'T'),
#  ('K', 'B'),
#  ('L', 'U'),
#  ('M', 'D'),
#  ('N', 'H'),
#  ('O', 'X'),
#  ('P', 'Z'),
#  ('Q', 'I'),
#  ('R', 'J'),
#  ('S', 'E'),
#  ('T', 'G'),
#  ('U', 'S'),
#  ('V', 'C'),
#  ('W', 'L'),
#  ('X', 'Y'),
#  ('Y', 'F'),
#  ('Z', 'M')]

# %%
actual_mapping_list
# Out:
# [('A', 'B'),
#  ('B', 'O'),
#  ('C', 'I'),
#  ('D', 'H'),
#  ('E', 'G'),
#  ('F', 'K'),
#  ('G', 'N'),
#  ('H', 'Q'),
#  ('I', 'V'),
#  ('J', 'T'),
#  ('K', 'W'),
#  ('L', 'Y'),
#  ('M', 'U'),
#  ('N', 'R'),
#  ('O', 'X'),
#  ('P', 'Z'),
#  ('Q', 'A'),
#  ('R', 'J'),
#  ('S', 'E'),
#  ('T', 'M'),
#  ('U', 'S'),
#  ('V', 'L'),
#  ('W', 'D'),
#  ('X', 'F'),
#  ('Y', 'P'),
#  ('Z', 'C')]

# %%
def find_how_many_correctly_matched_and_how_many_incorrectly(cipher_mapping, actual_mapping):
    correct = 0
    incorrect = 0
    
    corrects = []
    incorrects = []
    
    for k, v in cipher_mapping.items():
        if v == actual_mapping[k]:
            correct += 1
            corrects.append((k, v))
        else:
            incorrect += 1
            incorrects.append((k, v))
        
    
    
    return correct, incorrect, corrects, incorrects

# %%
correct, incorrect, corrects, incorrects = find_how_many_correctly_matched_and_how_many_incorrectly(mapping, actual_mapping)

# %%
print(correct)
corrects
# Out:
# 8
# [('S', 'E'),
#  ('J', 'T'),
#  ('B', 'O'),
#  ('U', 'S'),
#  ('R', 'J'),
#  ('O', 'X'),
#  ('H', 'Q'),
#  ('P', 'Z')]

# %%
print(incorrect)
incorrects
# Out:
# 18
# [('G', 'A'),
#  ('Q', 'I'),
#  ('C', 'N'),
#  ('N', 'H'),
#  ('D', 'R'),
#  ('M', 'D'),
#  ('W', 'L'),
#  ('V', 'C'),
#  ('L', 'U'),
#  ('Z', 'M'),
#  ('E', 'W'),
#  ('Y', 'F'),
#  ('T', 'G'),
#  ('X', 'Y'),
#  ('F', 'P'),
#  ('K', 'B'),
#  ('A', 'V'),
#  ('I', 'K')]

# %%
x = np.array(list(cipher_freq.keys()))
y = np.array(list(cipher_freq.values()))

# plot 
import matplotlib.pyplot as plt
plt.bar(x, y)
plt.xlabel('Letter')
plt.ylabel('Frequency (%)')
plt.title('Relative frequency of letters in the English language')

# annotate it
for i, j in zip(x, y):
    plt.text(i, j, str(j), ha='center', va='bottom')

# %%
plot_frequency(frequency_dict)

# %%
helper(cipher_freq)

# %%
def helper(arr):    
    arr = list(arr.items())
    arr.sort(key=lambda x: x[1], reverse=True)

    x = [i[0] for i in arr]
    y = [i[1] for i in arr]

    plt.bar(x, y)
    plt.xlabel('Letter')
    plt.ylabel('Frequency (%)')
    plt.title('Relative frequency of letters(in CipherText)')

    for i, j in zip(x, y):
        format_to_2_decimal = "{:.2f}".format(j)
        plt.text(i, j, format_to_2_decimal, ha='center', va='bottom')
